# %%
import pandas as pd

# %%
df = pd.read_csv('filtered gabung jakbar&jaksel - Sheet1.csv')

# %%
df['full_text'] = df['full_text'].str.lower()

# %%
df.to_csv('filtered_gabung_lower.csv', index=False)
