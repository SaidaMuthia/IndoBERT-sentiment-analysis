# %%
#Import packages
import pandas as pd
import numpy as np
import re

# %%
#Membaca CSV hasil crawling menjadi DataFrame
df = pd.read_csv("/content/nestle.csv")

# %%
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1782440629316046913  Mon Apr 22 16:06:11 +0000 2024               1
# 1  1782440396829982763  Mon Apr 22 16:04:58 +0000 2024               0
# 2  1782438510122914090  Mon Apr 22 16:01:32 +0000 2024               0
# 3  1782414740213657613  Mon Apr 22 15:58:44 +0000 2024               0
# 4  1782430160782033309  Mon Apr 22 15:56:21 +0000 2024               1
#
#                                            full_text               id_str  \
# 0  @sataninthehouse murah banget lgsg wa aja ya. ...  1782440774229180626
# 1  @arsencowo 2k/cek murah banget lgsg wa aja ya....  1782440467105505664
# 2  @kdrama_menfess apeeee nderrr apeee nonton keh...  1782439606274961783
# 3  @kdrama_menfess episode 5 ini gemeshhh bgttt f...  1782438901380210851
# 4   @kdrama_menfess aku yakin sunjae gk jadi ubi kok  1782438299124330517
#
#                                          image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/media/GLyAY8JbkAAKTsB.jpg         sataninthehouse
# 1                                              NaN               arsencowo
# 2                                              NaN          kdrama_menfess
# 3                                              NaN          kdrama_menfess
# 4                                              NaN          kdrama_menfess
#
#   lang  location  quote_count  reply_count  retweet_count  \
# 0   in  order 👉🏼            0            0              0
# 1   in  order 👉🏼            0            0              0
# 2   in       NaN            0            0              0
# 3   in       NaN            0            0              0
# 4   in       NaN            0            0              0
#
#                                            tweet_url          user_id_str  \
# 0  https://twitter.com/losingmimx/status/17824407...  1216826967174995969
# 1  https://twitter.com/losingmimx/status/17824404...  1216826967174995969
# 2  https://twitter.com/needmoreindomie/status/178...  1404827968107548672
# 3  https://twitter.com/needmoreindomie/status/178...  1404827968107548672
# 4  https://twitter.com/needmoreindomie/status/178...  1404827968107548672
#
#           username
# 0       losingmimx
# 1       losingmimx
# 2  needmoreindomie
# 3  needmoreindomie
# 4  needmoreindomie

# %%
#Membuat DataFrame baru dengan kolom "full_text", yang diisi dengan kolom "full_text" dari DataFrame original
new_df = {
    "full_text" : df.full_text,
}

new_df = pd.DataFrame(new_df)

new_df.head()
# Out:
#                                            full_text
# 0  @sataninthehouse murah banget lgsg wa aja ya. ...
# 1  @arsencowo 2k/cek murah banget lgsg wa aja ya....
# 2  @kdrama_menfess apeeee nderrr apeee nonton keh...
# 3  @kdrama_menfess episode 5 ini gemeshhh bgttt f...
# 4   @kdrama_menfess aku yakin sunjae gk jadi ubi kok

# %%
def remove_urls(text):
    # Define the regex pattern to match URLs
    url_pattern = r'https?://\S+|www\.\S+'

    # Use the sub() function to replace URLs with an empty string
    return re.sub(url_pattern, '', text)

# %%
def remove_tags(text):
    # Define the regex pattern to match tags
    tags_pattern = r'#\S+'

    # Use the sub() function to replace tags with an empty string
    return re.sub(tags_pattern, '', text)

# %%
def remove_mentions(text):
    # Define the regex pattern to match mentions
    mention_pattern = r'@\S+'

    # Use the sub() function to replace mentions with an empty string
    return re.sub(mention_pattern, '', text)

# %%
new_df.full_text
# Out:
# 0      @sataninthehouse murah banget lgsg wa aja ya. ...
# 1      @arsencowo 2k/cek murah banget lgsg wa aja ya....
# 2      @kdrama_menfess apeeee nderrr apeee nonton keh...
# 3      @kdrama_menfess episode 5 ini gemeshhh bgttt f...
# 4       @kdrama_menfess aku yakin sunjae gk jadi ubi kok
#                              ...
# 949    Ria ricis ada campaign sama KFC di hujat tp ma...
# 950    Mesen americano tapi malah di kasih kopi Nestl...
# 951    @Musanathi2 Ha a sana! Have you tasted Nestle?...
# 952                           @lileenaaa Nestle bunyaaad
# 953      nestle .kamu .sampe kapan .harus aku .boikot ..
# Name: full_text, Length: 954, dtype: object

# %%
# Mengeksekusi fungsi ke setiap baris dataframe yang ada
new_df = new_df.full_text.apply(remove_urls).apply(remove_tags).apply(remove_mentions)

# %%
new_df
# Out:
# 0       murah banget lgsg wa aja ya. Payment ready al...
# 1       2k/cek murah banget lgsg wa aja ya. Payment r...
# 2             apeeee nderrr apeee nonton kehaluan luu???
# 3              episode 5 ini gemeshhh bgttt full nyengir
# 4                       aku yakin sunjae gk jadi ubi kok
#                              ...
# 949    Ria ricis ada campaign sama KFC di hujat tp ma...
# 950    Mesen americano tapi malah di kasih kopi Nestl...
# 951     Ha a sana! Have you tasted Nestle? Lawa ingat...
# 952                                      Nestle bunyaaad
# 953      nestle .kamu .sampe kapan .harus aku .boikot ..
# Name: full_text, Length: 954, dtype: object

# %%
# Menyimpan DataFrame baru menjadi CSV, dengan nama yang diberikan di parameter
new_df.to_csv("cleaned_nestle.csv")
